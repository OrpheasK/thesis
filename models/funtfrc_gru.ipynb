# %%
import csv
import os
import gc
import numpy as np
import tensorflow as tf
from random import randint
from tensorflow import keras
from keras.utils import np_utils, plot_model, to_categorical
from keras.models import Model
from keras.layers import Input, GRU, Dense, RepeatVector, TimeDistributed, concatenate

# %%
# returns train, inference_encoder and inference_decoder models
def define_models(dim_p, n_units):
	# define training encoder
	enc_in_o = Input(shape=(None, 1))
	enc_in_q = Input(shape=(None, 1))
	enc_in_p = Input(shape=(None, dim_p))
	encoder_inputs = concatenate([enc_in_o, enc_in_q, enc_in_p])
	encoder = GRU(n_units, return_state=True)
	encoder_outputs, state_h = encoder(encoder_inputs)
	
	# define training decoder
	dec_in_o = Input(shape=(None, 1))
	dec_in_q = Input(shape=(None, 1))
	dec_in_p = Input(shape=(None, dim_p))
	decoder_inputs = concatenate([dec_in_o, dec_in_q, dec_in_p])
	decoder_gru = GRU(n_units, return_sequences=True, return_state=True)
	decoder_outputs, _ = decoder_gru(decoder_inputs, initial_state=state_h)
	dec_dense_o = Dense(1, activation='relu', name='tr_out_o')
	dec_dense_q = Dense(1, activation='sigmoid', name='tr_out_q')
	dec_dense_p = Dense(dim_p, activation='softmax', name='tr_out_p')
	#out_o = Dense(1, activation='relu', name='tr_out_o')(decoder_outputs)#act relu
	#out_q = Dense(1, activation='sigmoid', name='tr_out_q')(decoder_outputs)
	#out_p = Dense(dim_p, activation='softmax', name='tr_out_p')(decoder_outputs)
	out_o = dec_dense_o(decoder_outputs)
	out_q = dec_dense_q(decoder_outputs)
	out_p = dec_dense_p(decoder_outputs)
	
	model = Model([enc_in_o, enc_in_q, enc_in_p, dec_in_o, dec_in_q, dec_in_p], [out_o, out_q, out_p])
	
	# define inference encoder
	encoder_model = Model([enc_in_o, enc_in_q, enc_in_p], state_h)
	
	# define inference decoder
	decoder_state_input_h = Input(shape=(n_units,))
	decoder_outputs, state_h = decoder_gru(decoder_inputs, initial_state=decoder_state_input_h)
	#out_o = TimeDistributed(Dense(1, activation='relu'))(decoder_outputs)#act relu
	#out_q = TimeDistributed(Dense(1, activation='sigmoid'))(decoder_outputs)
	#out_p = TimeDistributed(Dense(dim_p, activation='softmax'))(decoder_outputs)
	out_o = dec_dense_o(decoder_outputs)
	out_q = dec_dense_q(decoder_outputs)
	out_p = dec_dense_p(decoder_outputs)
	
	decoder_model = Model([dec_in_o, dec_in_q, dec_in_p] + [decoder_state_input_h], [out_o, out_q, out_p] + [state_h])
	# return all models
	return model, encoder_model, decoder_model
 
# generate target given source sequence
def predict_sequence(infenc, infdec, src_o, src_q, src_p, n_steps, cardinality):
	# encode
	state = infenc.predict([src_o, src_q, src_p])
	# start of sequence input
	target_o = np.array([-1]).reshape(1, 1, 1)
	target_q = np.array([-1]).reshape(1, 1, 1)
	target_p = 0
	target_p = to_categorical(target_p, cardinality).reshape((1,1,-1))
	# collect predictions
	output = list()
	for t in range(n_steps):
		# predict next char
		#print(target_o.shape)
		#print(target_q.shape)
		#print(target_p.shape)
		#print(state[0].shape)
		o, q, p, h, = infdec.predict([target_o, target_q, target_p] + [state])
		#print(a)
		# store prediction
		output.append(o[0,0,:])
		output.append(q[0,0,:])
		output.append(p[0,0,:])
		# update state
		state = h
		# update target sequence
		target_o = o
		target_q = q
		target_p = p
	return np.array(output)
 
# decode a one hot encoded string
def one_hot_decode(encoded_seq):
	return [np.argmax(vector) for vector in encoded_seq]

# %%
#load data
stream_list = []

for directory, subdirectories, files in os.walk('data'):
    for file in files:
        with open('data/' + file, 'r') as f: 
            reader = csv.reader(f)
            sub_list = [list(map(float,rec)) for rec in csv.reader(f, delimiter=',')]
            stream_list = stream_list + sub_list

# %%
#create seperate data structures for each variable (offset, quarterlength, pitch)
#normalise offset and quarterlength
offs = []
qlngth = []
ptch = []

offsb = max(element[0] for element in stream_list)
qlngthb = max(element[1] for element in stream_list)
#ptchb = 127.0

for row in stream_list:
    offs.append(row[0]/offsb)
    qlngth.append(row[1]/qlngthb)
    ptch.append(row[2])

# %%
del stream_list
gc.collect()
# Out:
# 128

# %%
#divide the sets in sequences of specific length 
dtlngth=len(offs)
seq_length = 4#100 groups of 3

dataX1_o = []
dataX1_q = []
dataX1_p = []
dataX2_o = []
dataX2_q = []
dataX2_p = []

for i in range(0, dtlngth - seq_length + 1, 1):
	seq_in_o = offs[i:i + seq_length]
	seq_in_q = qlngth[i:i + seq_length]
	seq_in_p = ptch[i:i + seq_length]

	# create padded input target sequence
	target_in_o = [-1] + seq_in_o[:-1]
	target_in_q = [-1] + seq_in_q[:-1]
	target_in_p = [0] + seq_in_p[:-1]
	
	src_encoded = to_categorical(seq_in_p, num_classes=127+1)
	tar2_encoded = to_categorical(target_in_p, num_classes=127+1)
	
	dataX1_o.append([offs for offs in seq_in_o])
	dataX1_q.append([qlngth for qlngth in seq_in_q])
	dataX1_p.append(src_encoded)
	dataX2_o.append([offs for offs in target_in_o])
	dataX2_q.append([qlngth for qlngth in target_in_q])
	dataX2_p.append(tar2_encoded)

n_patterns = len(dataX1_p)
print ("Total Patterns: ", n_patterns)
# Out:
# Total Patterns:  32385

# %%
#reshape inputs to be [samples, time steps, features], one hot encode pitch output
dataX1_o = np.reshape(dataX1_o, (n_patterns, seq_length, 1))
dataX1_q = np.reshape(dataX1_q, (n_patterns, seq_length, 1))

dataX2_o = np.reshape(dataX2_o, (n_patterns, seq_length, 1))
dataX2_q = np.reshape(dataX2_q, (n_patterns, seq_length, 1))

# %%
del offs
del qlngth
del ptch
gc.collect()
# Out:
# 44

# %%
#divide data in train and validation sets
dataX1_o_tr = dataX1_o[:-1000]
dataX1_o_v = dataX1_o[-1000:]
dataX2_o_tr = dataX2_o[:-1000]
dataX2_o_v = dataX2_o[-1000:]

dataX1_q_tr = dataX1_q[:-1000]
dataX1_q_v = dataX1_q[-1000:]
dataX2_q_tr = dataX2_q[:-1000]
dataX2_q_v = dataX2_q[-1000:]

dataX1_p_tr = dataX1_p[:-1000]
dataX1_p_v = dataX1_p[-1000:]
dataX2_p_tr = dataX2_p[:-1000]
dataX2_p_v = dataX2_p[-1000:]

# %%
# configure problem
n_features = np.array(dataX2_p).shape[2]
n_steps_in = 4
n_steps_out = 4
# define model
train, infenc, infdec = define_models(n_features, 256)
train.compile(optimizer='adam', loss={'tr_out_o': 'mse', 'tr_out_q': 'mse', 'tr_out_p': 'categorical_crossentropy'},
 metrics={'tr_out_o': 'mean_squared_error', 'tr_out_q': 'mean_squared_error', 'tr_out_p': 'accuracy'})

# %%
# train model
train.fit([dataX1_o_tr, dataX1_q_tr, np.array(dataX1_p_tr), dataX2_o_tr, dataX2_q_tr, np.array(dataX2_p_tr)], [dataX1_o_tr, dataX1_q_tr, np.array(dataX1_p_tr)], epochs=10)
# Out:
# Epoch 1/10
# 981/981 [==============================] - 55s 56ms/step - loss: 1.1937 - tr_out_o_loss: 0.0072 - tr_out_q_loss: 0.0038 - tr_out_p_loss: 1.1827 - tr_out_o_mean_squared_error: 0.0072 - tr_out_q_mean_squared_error: 0.0038 - tr_out_p_accuracy: 0.6799
# Epoch 2/10
# 981/981 [==============================] - 56s 57ms/step - loss: 0.0778 - tr_out_o_loss: 0.0032 - tr_out_q_loss: 0.0014 - tr_out_p_loss: 0.0732 - tr_out_o_mean_squared_error: 0.0032 - tr_out_q_mean_squared_error: 0.0014 - tr_out_p_accuracy: 0.9868
# Epoch 3/10
# 981/981 [==============================] - 56s 57ms/step - loss: 0.0186 - tr_out_o_loss: 0.0014 - tr_out_q_loss: 0.0013 - tr_out_p_loss: 0.0159 - tr_out_o_mean_squared_error: 0.0014 - tr_out_q_mean_squared_error: 0.0013 - tr_out_p_accuracy: 0.9984
# Epoch 4/10
# 981/981 [==============================] - 55s 56ms/step - loss: 0.0107 - tr_out_o_loss: 8.1902e-04 - tr_out_q_loss: 0.0012 - tr_out_p_loss: 0.0087 - tr_out_o_mean_squared_error: 8.1902e-04 - tr_out_q_mean_squared_error: 0.0012 - tr_out_p_accuracy: 0.9990
# Epoch 5/10
# 981/981 [==============================] - 54s 55ms/step - loss: 0.0072 - tr_out_o_loss: 5.8498e-04 - tr_out_q_loss: 9.8370e-04 - tr_out_p_loss: 0.0057 - tr_out_o_mean_squared_error: 5.8498e-04 - tr_out_q_mean_squared_error: 9.8370e-04 - tr_out_p_accuracy: 0.9993
# Epoch 6/10
# 981/981 [==============================] - 55s 56ms/step - loss: 0.0054 - tr_out_o_loss: 4.7537e-04 - tr_out_q_loss: 8.1904e-04 - tr_out_p_loss: 0.0041 - tr_out_o_mean_squared_error: 4.7537e-04 - tr_out_q_mean_squared_error: 8.1904e-04 - tr_out_p_accuracy: 0.9994
# Epoch 7/10
# 981/981 [==============================] - 55s 56ms/step - loss: 0.0052 - tr_out_o_loss: 4.1721e-04 - tr_out_q_loss: 7.6564e-04 - tr_out_p_loss: 0.0040 - tr_out_o_mean_squared_error: 4.1721e-04 - tr_out_q_mean_squared_error: 7.6564e-04 - tr_out_p_accuracy: 0.9994
# Epoch 8/10
# 981/981 [==============================] - 54s 55ms/step - loss: 0.0054 - tr_out_o_loss: 4.2006e-04 - tr_out_q_loss: 7.2660e-04 - tr_out_p_loss: 0.0042 - tr_out_o_mean_squared_error: 4.2006e-04 - tr_out_q_mean_squared_error: 7.2660e-04 - tr_out_p_accuracy: 0.9991
# Epoch 9/10
# 981/981 [==============================] - 55s 56ms/step - loss: 0.0037 - tr_out_o_loss: 3.2879e-04 - tr_out_q_loss: 6.5049e-04 - tr_out_p_loss: 0.0027 - tr_out_o_mean_squared_error: 3.2879e-04 - tr_out_q_mean_squared_error: 6.5049e-04 - tr_out_p_accuracy: 0.9995
# Epoch 10/10
# 981/981 [==============================] - 54s 55ms/step - loss: 0.0035 - tr_out_o_loss: 3.3532e-04 - tr_out_q_loss: 6.5319e-04 - tr_out_p_loss: 0.0025 - tr_out_o_mean_squared_error: 3.3532e-04 - tr_out_q_mean_squared_error: 6.5319e-04 - tr_out_p_accuracy: 0.9995

# %%
infdec.summary()

# %%
# spot check some examples
for _ in range(10):
    i = randint(1, 1000)
    X1_o = np.reshape(dataX1_o_v[i], (1, seq_length, 1))
    X1_q = np.reshape(dataX1_q_v[i], (1, seq_length, 1))
    X1_p = np.reshape(dataX1_p_v[i], (1, seq_length, n_features))
    target = predict_sequence(infenc, infdec, X1_o, X1_q, X1_p, n_steps_out, n_features)
    for j in range(seq_length):
        print('X_o=%s, y_o=%s, X_q=%s, y_q=%s, X_p=%s, y_p=%s' % (dataX1_o_v[i][j]*offsb, target[3*j]*offsb, dataX1_q_v[i][j]*qlngthb, target[3*j+1]*qlngthb, one_hot_decode([dataX1_p_v[i][j]]), one_hot_decode([target[3*j+2]])))
    print()
# Out:
# X_o=[452.], y_o=[449.56598], X_q=[1.5], y_q=[1.3300873], X_p=[57], y_p=[57]
# X_o=[455.], y_o=[459.5011], X_q=[0.75], y_q=[0.6635941], X_p=[33], y_p=[33]
# X_o=[456.], y_o=[455.61832], X_q=[1.25], y_q=[1.3308741], X_p=[69], y_p=[69]
# X_o=[456.], y_o=[453.1969], X_q=[1.25], y_q=[0.96714866], X_p=[74], y_p=[74]
#
# X_o=[481.5], y_o=[483.35266], X_q=[1.5], y_q=[0.78058094], X_p=[71], y_p=[71]
# X_o=[481.5], y_o=[473.91415], X_q=[1.5], y_q=[0.5334712], X_p=[74], y_p=[74]
# X_o=[481.5], y_o=[476.45978], X_q=[1.33333333], y_q=[0.59748554], X_p=[79], y_p=[79]
# X_o=[481.5], y_o=[474.43454], X_q=[0.25], y_q=[0.699861], X_p=[31], y_p=[31]
#
# X_o=[521.5], y_o=[534.6348], X_q=[1.5], y_q=[0.8565914], X_p=[74], y_p=[74]
# X_o=[521.5], y_o=[531.3925], X_q=[1.5], y_q=[0.5478591], X_p=[78], y_p=[78]
# X_o=[521.5], y_o=[533.4022], X_q=[0.25], y_q=[0.23902059], X_p=[35], y_p=[35]
# X_o=[521.5], y_o=[550.1788], X_q=[0.5], y_q=[1.1893027], X_p=[61], y_p=[61]
#
# X_o=[436.], y_o=[441.3416], X_q=[1.], y_q=[0.43449885], X_p=[76], y_p=[76]
# X_o=[436.], y_o=[443.75482], X_q=[1.25], y_q=[0.5245853], X_p=[33], y_p=[33]
# X_o=[436.], y_o=[446.09073], X_q=[1.5], y_q=[1.9448038], X_p=[76], y_p=[76]
# X_o=[436.], y_o=[454.10278], X_q=[1.5], y_q=[2.0019314], X_p=[69], y_p=[69]
#
# X_o=[353.5], y_o=[344.75156], X_q=[0.25], y_q=[0.94388723], X_p=[31], y_p=[31]
# X_o=[354.], y_o=[352.2226], X_q=[1.75], y_q=[1.4521077], X_p=[31], y_p=[31]
# X_o=[356.], y_o=[346.2324], X_q=[1.], y_q=[0.7938668], X_p=[69], y_p=[69]
# X_o=[356.], y_o=[348.53088], X_q=[1.], y_q=[0.55581963], X_p=[73], y_p=[73]
#
# X_o=[353.5], y_o=[345.27603], X_q=[1.5], y_q=[0.7103138], X_p=[74], y_p=[74]
# X_o=[353.5], y_o=[343.63498], X_q=[1.25], y_q=[1.353797], X_p=[79], y_p=[79]
# X_o=[353.5], y_o=[345.17313], X_q=[0.25], y_q=[0.9390112], X_p=[31], y_p=[31]
# X_o=[354.], y_o=[342.78528], X_q=[1.75], y_q=[0.42355323], X_p=[31], y_p=[31]
#
# X_o=[280.], y_o=[278.91553], X_q=[0.], y_q=[0.7120818], X_p=[79], y_p=[79]
# X_o=[280.], y_o=[278.67035], X_q=[3.5], y_q=[1.1819746], X_p=[71], y_p=[71]
# X_o=[280.], y_o=[274.27], X_q=[3.5], y_q=[0.6069794], X_p=[76], y_p=[76]
# X_o=[280.], y_o=[270.33978], X_q=[3.25], y_q=[1.639194], X_p=[79], y_p=[79]
#
# X_o=[448.], y_o=[449.59842], X_q=[4.], y_q=[1.9874599], X_p=[55], y_p=[55]
# X_o=[448.], y_o=[450.54257], X_q=[3.5], y_q=[1.0386553], X_p=[71], y_p=[71]
# X_o=[448.], y_o=[437.04883], X_q=[3.5], y_q=[1.2321879], X_p=[74], y_p=[74]
# X_o=[448.], y_o=[442.93945], X_q=[3.25], y_q=[1.5982468], X_p=[79], y_p=[79]
#
# X_o=[277.5], y_o=[266.2909], X_q=[1.75], y_q=[0.5791515], X_p=[71], y_p=[71]
# X_o=[277.5], y_o=[266.8933], X_q=[1.5], y_q=[0.3938746], X_p=[76], y_p=[76]
# X_o=[277.5], y_o=[276.85455], X_q=[1.25], y_q=[0.38416946], X_p=[80], y_p=[80]
# X_o=[277.5], y_o=[268.02222], X_q=[0.25], y_q=[0.20911619], X_p=[28], y_p=[28]
#
# X_o=[333.75], y_o=[322.6823], X_q=[1.25], y_q=[0.52768886], X_p=[76], y_p=[76]
# X_o=[334.], y_o=[325.86676], X_q=[1.], y_q=[0.44871792], X_p=[28], y_p=[28]
# X_o=[334.5], y_o=[332.82004], X_q=[1.25], y_q=[0.45241937], X_p=[62], y_p=[62]
# X_o=[335.], y_o=[318.99667], X_q=[0.75], y_q=[0.4206341], X_p=[30], y_p=[30]

# %%
target
# Out:
# array([array([0.6091928], dtype=float32),
#        array([0.81667787], dtype=float32),
#        array([0.02832382, 0.00506055, 0.00252124, 0.00338739, 0.00328134,
#        0.0043051 , 0.00730426, 0.00505911, 0.00732537, 0.00692601,
#        0.01266262, 0.00638036, 0.00602316, 0.00630103, 0.00870636,
#        0.00274761, 0.00915835, 0.00475388, 0.01208431, 0.00919578,
#        0.01092449, 0.00631092, 0.01472623, 0.00756396, 0.00691384,
#        0.00448319, 0.00763378, 0.00508943, 0.00458313, 0.0024238 ,
#        0.0024929 , 0.01170231, 0.00595025, 0.01534734, 0.00422082,
#        0.00325   , 0.01816621, 0.00512767, 0.01175208, 0.01093599,
#        0.00672235, 0.00469713, 0.02320295, 0.0085847 , 0.00402998,
#        0.00713945, 0.00365347, 0.00451266, 0.01456772, 0.01473746,
#        0.00876913, 0.00495217, 0.01188774, 0.01027179, 0.00510809,
#        0.01228774, 0.00407863, 0.00992823, 0.00197576, 0.00431416,
#        0.00362944, 0.00733132, 0.01178547, 0.00223031, 0.00690317,
#        0.01109138, 0.00861269, 0.01545872, 0.00800875, 0.00966255,
#        0.00917761, 0.01316907, 0.00397657, 0.00495467, 0.00754687,
#        0.01102219, 0.00732802, 0.00259342, 0.00944116, 0.01969   ,
#        0.00314388, 0.00589018, 0.00773749, 0.01349492, 0.01468438,
#        0.00293447, 0.01065848, 0.00571501, 0.0042814 , 0.0065104 ,
#        0.00502465, 0.00229045, 0.00725147, 0.0053219 , 0.00690065,
#        0.00520432, 0.01010556, 0.00539281, 0.00318502, 0.00291553,
#        0.00283667, 0.00412811, 0.01573701, 0.00553136, 0.00737782,
#        0.02100813, 0.01682698, 0.00885787, 0.00151192, 0.00993492,
#        0.00359686, 0.00646726, 0.01448665, 0.00534329, 0.01437153,
#        0.00467043, 0.01498833, 0.00208647, 0.0093574 , 0.01075099,
#        0.00266906, 0.00295645, 0.00270944, 0.00615382, 0.00454765,
#        0.01556066, 0.00221624, 0.00453307], dtype=float32),
#        array([0.6379769], dtype=float32),
#        array([0.87476027], dtype=float32),
#        array([0.02485091, 0.00457694, 0.00190326, 0.00196203, 0.0030022 ,
#        0.00294785, 0.0054349 , 0.00663586, 0.00604093, 0.00736485,
#        0.01384575, 0.00656411, 0.00705524, 0.00939274, 0.00961194,
#        0.00350261, 0.00808133, 0.00466005, 0.01474883, 0.01618228,
#        0.00935893, 0.00533331, 0.00990598, 0.00673268, 0.00642311,
#        0.00538839, 0.00914633, 0.00414899, 0.00442833, 0.0027902 ,
#        0.00238814, 0.01265717, 0.00702376, 0.01424824, 0.00351924,
#        0.00212901, 0.01523055, 0.00603779, 0.01024793, 0.0079151 ,
#        0.00890524, 0.00546224, 0.0205961 , 0.00810189, 0.00468438,
#        0.00754881, 0.00247688, 0.00545799, 0.01002109, 0.01443708,
#        0.0069669 , 0.00534136, 0.01044245, 0.00918587, 0.00457042,
#        0.01063301, 0.00539522, 0.00934459, 0.00147761, 0.00464831,
#        0.00478526, 0.00819007, 0.0107376 , 0.00319574, 0.00433787,
#        0.01351734, 0.00728063, 0.01330467, 0.00733445, 0.0083026 ,
#        0.00824181, 0.01437484, 0.00418806, 0.00501631, 0.0110124 ,
#        0.01071102, 0.00647455, 0.00215236, 0.01109621, 0.02064026,
#        0.00434613, 0.00493573, 0.01054691, 0.00864149, 0.01216346,
#        0.00428472, 0.010492  , 0.00790053, 0.0037479 , 0.00512554,
#        0.00456669, 0.00260749, 0.00831076, 0.00625389, 0.00756611,
#        0.00636886, 0.01489337, 0.00345482, 0.00312389, 0.00262014,
#        0.00328246, 0.00351555, 0.02267666, 0.00602443, 0.01028787,
#        0.02263235, 0.01406246, 0.01101024, 0.0013951 , 0.0109286 ,
#        0.00429479, 0.00693497, 0.01457404, 0.00514435, 0.01099306,
#        0.00420672, 0.02047491, 0.00235144, 0.00552557, 0.00968836,
#        0.00205523, 0.00398496, 0.00379463, 0.00604878, 0.00429695,
#        0.01661618, 0.00240742, 0.00483234], dtype=float32),
#        array([0.5194144], dtype=float32),
#        array([0.84811294], dtype=float32),
#        array([0.02028297, 0.00491526, 0.00186239, 0.00119161, 0.00343476,
#        0.00252321, 0.00545329, 0.00884071, 0.00539765, 0.0070326 ,
#        0.01270262, 0.00635313, 0.00853416, 0.00933985, 0.01207732,
#        0.00356361, 0.00617238, 0.00503713, 0.01766618, 0.02108772,
#        0.00854499, 0.00484699, 0.0062156 , 0.00781036, 0.00603529,
#        0.00575668, 0.01299171, 0.00357503, 0.00395947, 0.0034456 ,
#        0.0020765 , 0.01561222, 0.01026403, 0.01001124, 0.00250556,
#        0.00151939, 0.01806785, 0.00877197, 0.00887795, 0.00607438,
#        0.0088189 , 0.00688489, 0.01512965, 0.00637553, 0.00626602,
#        0.00787583, 0.00182328, 0.00605126, 0.00891529, 0.01451517,
#        0.00685945, 0.00483712, 0.01028727, 0.00666743, 0.00465867,
#        0.00973422, 0.00582584, 0.01032632, 0.00133702, 0.00505746,
#        0.00573035, 0.00832758, 0.00967079, 0.00589038, 0.00272292,
#        0.01410165, 0.0074514 , 0.01171785, 0.00476392, 0.00629378,
#        0.00707387, 0.01645024, 0.00399554, 0.00657538, 0.01201266,
#        0.0093849 , 0.00636818, 0.00181248, 0.01024669, 0.01383225,
#        0.00428188, 0.00395219, 0.01139925, 0.00729966, 0.00782974,
#        0.00542168, 0.00740344, 0.00959122, 0.00394028, 0.00396944,
#        0.0047349 , 0.00359158, 0.0088151 , 0.00685151, 0.00791957,
#        0.01040746, 0.01203996, 0.00280158, 0.00320748, 0.00219842,
#        0.00378688, 0.00322779, 0.02790613, 0.00713245, 0.01864777,
#        0.02007724, 0.01035399, 0.01099243, 0.00172112, 0.01273156,
#        0.00635625, 0.00632968, 0.01266996, 0.00557792, 0.00701845,
#        0.00341106, 0.02501204, 0.00257552, 0.00348726, 0.01033776,
#        0.00161351, 0.00578024, 0.00416947, 0.00639238, 0.00506889,
#        0.01602911, 0.00331356, 0.00752248], dtype=float32),
#        array([0.42369336], dtype=float32),
#        array([0.76849794], dtype=float32),
#        array([0.01451272, 0.00651692, 0.00216154, 0.0007982 , 0.00315303,
#        0.00227084, 0.00507279, 0.0106606 , 0.0055202 , 0.00589758,
#        0.00981091, 0.00609973, 0.00942248, 0.00873544, 0.01547186,
#        0.00377892, 0.00459316, 0.00570908, 0.01990768, 0.01947454,
#        0.00878474, 0.00461471, 0.00415209, 0.00705395, 0.00527166,
#        0.00743564, 0.0123809 , 0.0031485 , 0.00301959, 0.00495056,
#        0.00206046, 0.0163783 , 0.01231967, 0.00543963, 0.00180304,
#        0.00118939, 0.02572986, 0.01381611, 0.00819874, 0.00519797,
#        0.00984167, 0.00781569, 0.01087722, 0.0050803 , 0.00736351,
#        0.00784818, 0.00135752, 0.00672452, 0.00920169, 0.01171775,
#        0.0066551 , 0.00452638, 0.00845461, 0.00460129, 0.00538796,
#        0.00951804, 0.00582717, 0.00967197, 0.00169076, 0.00511918,
#        0.00566795, 0.00835518, 0.0083326 , 0.01018696, 0.0019116 ,
#        0.01270882, 0.00767761, 0.0098838 , 0.003352  , 0.00493111,
#        0.00725337, 0.01599791, 0.0043068 , 0.01054624, 0.01094102,
#        0.00840709, 0.00623821, 0.00182084, 0.00904523, 0.01058501,
#        0.00505234, 0.00282616, 0.01047082, 0.00888929, 0.00528067,
#        0.00559937, 0.00647205, 0.01065934, 0.00376898, 0.00443238,
#        0.00479384, 0.00361296, 0.00984377, 0.00633938, 0.00924001,
#        0.01350793, 0.007197  , 0.00266421, 0.0031186 , 0.00180095,
#        0.00539961, 0.00301082, 0.02435859, 0.00849411, 0.03013239,
#        0.01635312, 0.0078898 , 0.01028367, 0.00205705, 0.01286815,
#        0.00863747, 0.00505594, 0.01131174, 0.00545999, 0.00522294,
#        0.00358454, 0.02661043, 0.00324184, 0.00218455, 0.00909479,
#        0.00124662, 0.00729991, 0.00477958, 0.00741412, 0.00518759,
#        0.01958946, 0.00531459, 0.01240304], dtype=float32)], dtype=object)

# %%
X1_o = np.reshape(dataX1_o[2], (1, 2, 1))
X1_q = np.reshape(dataX1_q[2], (1, 2, 1))
X1_p = np.reshape(dataX1_p[2], (1, 2, 86))
state = infenc.predict([X1_o, X1_q, X1_p])
state
#target_o = np.array([-1]).reshape(1, 1)
#target_q = np.array([-1]).reshape(1, 1)
#target_p = -1.0
#target_p = np_utils.to_categorical(target_p, num_classes=86)
#target_p = np.array(target_p.reshape(1, 86)
#yhat, h, c = infdec.predict([target_o, target_q, target_p] + state)
